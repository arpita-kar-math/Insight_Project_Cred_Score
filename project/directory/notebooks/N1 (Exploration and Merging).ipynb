# %%
#import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# %%time
#datasets containign information on the employees
people_df = pd.read_csv('people_export2.csv')
# Out:
# <string>:2: DtypeWarning: Columns (9,12) have mixed types.Specify dtype option on import or set low_memory=False.
# CPU times: user 6.51 s, sys: 687 ms, total: 7.2 s
# Wall time: 8.35 s

# %%
people_df.columns
# Out:
# Index(['Unnamed: 0', 'brand_uuid', 'id', 'full_name', 'company_slug', 'slug',
#        'email', 'job_title', 'location', 'is_c_level', 'working_since',
#        'working_until', 'is_current'],
#       dtype='object')

# %%
#getting rid of Unnamed column
people = people_df[['brand_uuid', 'id', 'full_name', 'company_slug', 'slug',
       'email', 'job_title', 'location', 'is_c_level', 'working_since',
       'working_until', 'is_current']]

# %%
people.shape
# Out:
# (1958464, 12)

# %%
print('Number of unique emails : ', people['email'].nunique())
print('Number of null email ids : ', people['email'].isnull().sum())
print('Number of unique company slugs : ', people['company_slug'].nunique())
print('Number of unique slugs : ', people['slug'].nunique())
# Out:
# Number of unique emails :  754510
# Number of null email ids :  1126309
# Number of unique company slugs :  266426
# Number of unique slugs :  1832124

# %%
#emails are not unique for people
people['email'].value_counts()
# Out:
# etoiles_31@hotmail.es            10
# makenahunt@yahoo.com             10
# sebastian.merkhoffer@web.de      10
# jking@northwestsynergyinc.com    10
# david_hanys@yahoo.com             9
#                                  ..
# gcecchin@kpmg.ca                  1
# schambers@mauidiveshop.com        1
# tisamwright@gmail.com             1
# tderstine@geiger.com              1
# jcaufield@seven10storage.com      1
# Name: email, Length: 754510, dtype: int64

# %%
people['slug'].value_counts()
# Out:
# {country=us,+language=en}      200
# {country=es,+language=es}      100
# {country=ae,+language=ar}       73
# es                              64
# {country=de,+language=de}       60
#                               ...
# leslie-ford-70601023             1
# alex-zajac-70a84746              1
# valentina-m-henao-05195a17b      1
# sumit-tripathi-85a7bb174         1
# zulema-bazan-85432568            1
# Name: slug, Length: 1832124, dtype: int64

# %%
#Reading in the dataframe with info on the brands
col_list = [ 'brand_id', 'brand_uuid', 'brand_name' ,'growth_score', 'sudden_growth_score', 'sudden_growth_delta',
              'acceleration_score','success_score','is_physical_products_brand', 'is_brickandmortar' ,'founded',
             'employees_count' ,'generic_reseller' , 'store_is_subdomain']
brand_data_chunk = pd.read_csv('people_cred_brand_data.csv', usecols = col_list , chunksize=500)

# %%
# %%time
#This is in case you use chunks in pandas to upload your file.
chunk_list = []  # append each chunk df here 

# Each chunk is in df format
for chunk in brand_data_chunk:      
    # Once the data filtering is done, append the chunk to list
    chunk_list.append(chunk)
    
# concat the list into dataframe 
brand_data = pd.concat(chunk_list)
# Out:
# CPU times: user 30 s, sys: 1.02 s, total: 31 s
# Wall time: 36 s

# %%
#This is in case you uploaded the dataset as a whole
#brand_data=brand_data_chunk

# %%
#head of brand_data dataframe
brand_data.head()
# Out:
#    brand_id      brand_uuid      brand_name  growth_score  \
# 0     17197          thekey  TheKey.Company       90.1626
# 1     17198             loq             LOQ       42.7846
# 2     17199  prim8teapparel         PRIM8TE       36.2267
# 3     17200   rickyandmicky   Ricky & Micky       36.7196
# 4     17202       mzwallace      MZ Wallace       50.7959
#
#    sudden_growth_score  sudden_growth_delta  acceleration_score  \
# 0              95.2407               5.0781             95.5051
# 1              16.8201             -25.9645             47.8179
# 2              42.0921               5.8654             50.5134
# 3              32.1556              -4.5640             49.1773
# 4               4.0522             -46.7437             47.1598
#
#    success_score is_physical_products_brand is_brickandmortar  founded  \
# 0        45.9109                       True             False   2017.0
# 1        46.1855                       True             False   2015.0
# 2        20.2461                       True             False   2017.0
# 3        31.8832                       True             False   2016.0
# 4        53.3311                       True              True   2000.0
#
#    employees_count generic_reseller store_is_subdomain
# 0              NaN            False              False
# 1              6.0            False              False
# 2              NaN            False              False
# 3              7.0            False              False
# 4             54.0            False              False

# %%
brand_data.shape
# Out:
# (2318677, 14)

# %%
#number of unique brand names
print('Number of unique brand names : ', brand_data['brand_name'].nunique())

#number of missing values in employee_count
print('Number of null employee counts : ', brand_data['employees_count'].isnull().sum())

#number of missing values in growth score and success score
print('Number of missing values in growth score is ', brand_data['growth_score'].isnull().sum())
print('Number of missing values in success score is ', brand_data['success_score'].isnull().sum())
# Out:
# Number of unique brand names :  2284858
# Number of null employee counts :  2234880
# Number of missing values in growth score is  0
# Number of missing values in success score is  0

# %%
#how many times do each brand name get repeated?
brand_data['brand_name'].value_counts()
# Out:
# Sarah                42
# shopmania            26
# Katie                23
# Ashley               20
# kerastase            20
#                      ..
# bellacerafloors       1
# coupe-coupon          1
# Want and More         1
# YouandIcollection     1
# yourdailypal          1
# Name: brand_name, Length: 2284858, dtype: int64

# %%
#Lets look at the number of people in the people
people['full_name'].isnull().sum()
# Out:
# 2

# %%
#null row with missing name
null_data_name = people[people['full_name'].isnull()]
null_data_name
# Out:
#             brand_uuid       id full_name company_slug      slug  \
# 1665            target    26337       NaN       target  gene-han
# 1608446  bodynutrition  2152348       NaN          NaN       NaN
#
#                             email  \
# 1665          gene.han@target.com
# 1608446  stacey@bodynutrition.com
#
#                                                  job_title  \
# 1665     Vice President, Innovation - New Ventures + Ac...
# 1608446                                                NaN
#
#                           location is_c_level              working_since  \
# 1665     San Francisco, California      False  2017-01-01 00:00:00+00:00
# 1608446                        NaN        NaN                        NaN
#
#         working_until is_current
# 1665              NaN       True
# 1608446           NaN        NaN

# %%
#checking datetime object
from datetime import datetime

# datetime object containing current date and time
now = datetime.now()
 
print("now =", now)
# Out:
# now = 2020-07-02 13:50:55.561628

# %%
#Investigating the is_current column in people_df
people['is_current'].value_counts()
# Out:
# True     1712403
# False     246060
# Name: is_current, dtype: int64

# %%
#filling in current date time in working_until
import numpy as np
#people.working_until = np.where(((people.working_until.isnull()) & (people.is_current == True)), datetime.now().strftime("%Y-%m-%d %H:%M:%S"), people.working_until)
people.loc[((people.working_until.isnull()) & (people.is_current == True)), 'working_until'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# %%
#checking if filled
#null row with missing name
null_data_name = people_df[people_df['full_name'].isnull()]
null_data_name
# Out:
#          Unnamed: 0     brand_uuid       id full_name company_slug      slug  \
# 1665           1665         target    26337       NaN       target  gene-han
# 1608446     1608446  bodynutrition  2152348       NaN          NaN       NaN
#
#                             email  \
# 1665          gene.han@target.com
# 1608446  stacey@bodynutrition.com
#
#                                                  job_title  \
# 1665     Vice President, Innovation - New Ventures + Ac...
# 1608446                                                NaN
#
#                           location is_c_level              working_since  \
# 1665     San Francisco, California      False  2017-01-01 00:00:00+00:00
# 1608446                        NaN        NaN                        NaN
#
#         working_until is_current
# 1665              NaN       True
# 1608446           NaN        NaN

# %%
people.head()
# Out:
#    brand_uuid       id       full_name       company_slug  \
# 0    motorola  2015583  Michaël Maarek  motorola-mobility
# 1        ford     3501     Matt Monroe                NaN
# 2      target    26647     Paul Melson             target
# 3  timberland  2105414      Doug Clark                NaN
# 4      anthem  1087431  Leslie Lampert             anthem
#
#                       slug                          email  \
# 0            michaelmaarek             lemike10@gmail.com
# 1     matt-monroe-18217749                            NaN
# 2                  pmelson              pmelson@gmail.com
# 3      doug-clark-7ba36615  dclark@newenglandfootwear.com
# 4  leslie-lampert-b8552a10      leslie.lampert@anthem.com
#
#                                            job_title  \
# 0                               Key Account Director
# 1            Licensing Manager at Ford Motor Company
# 2  Senior Director, Cybersecurity Threat Intellig...
# 3                           Chief Innovation Officer
# 4                                        Director II
#
#                             location is_c_level              working_since  \
# 0             London, United Kingdom      False  2014-08-01 00:00:00+00:00
# 1                                NaN      False                        NaN
# 2  Greater Minneapolis-St. Paul Area      False  2017-04-01 00:00:00+00:00
# 3              Durham, New Hampshire       True  1994-01-01 00:00:00+00:00
# 4           Old Orchard Beach, Maine      False  1996-03-01 00:00:00+00:00
#
#                working_until is_current       working_until
# 0  2016-12-01 00:00:00+00:00      False                  NaN
# 1        2020-07-02 14:22:30       True  2020-07-02 13:51:36
# 2        2020-07-02 14:22:30       True  2020-07-02 13:51:36
# 3  2008-01-01 00:00:00+00:00      False                  NaN
# 4        2020-07-02 14:22:30       True  2020-07-02 13:51:36

# %%
print('Number of missing values in working_since : ', people['working_since'].isnull().sum())
# Out:
# Number of missing values in working_since :  629308

# %%
#checking for missing values in is_c_level
print('Number of missing values in is_c_level : ', people['is_c_level'].isnull().sum())

#checking for missing values in is_current
print('Number of missing values in is_current : ', people['is_current'].isnull().sum())
# Out:
# Number of missing values in is_c_level :  2
# Number of missing values in is_current :  1

# %%
#If a person is c_level, then value 1, if not , then 0
people['is_c_level'] = people['is_c_level'].replace({True :1 , False : 0})
people.head()
# Out:
#    brand_uuid       id       full_name       company_slug  \
# 0    motorola  2015583  Michaël Maarek  motorola-mobility
# 1        ford     3501     Matt Monroe                NaN
# 2      target    26647     Paul Melson             target
# 3  timberland  2105414      Doug Clark                NaN
# 4      anthem  1087431  Leslie Lampert             anthem
#
#                       slug                          email  \
# 0            michaelmaarek             lemike10@gmail.com
# 1     matt-monroe-18217749                            NaN
# 2                  pmelson              pmelson@gmail.com
# 3      doug-clark-7ba36615  dclark@newenglandfootwear.com
# 4  leslie-lampert-b8552a10      leslie.lampert@anthem.com
#
#                                            job_title  \
# 0                               Key Account Director
# 1            Licensing Manager at Ford Motor Company
# 2  Senior Director, Cybersecurity Threat Intellig...
# 3                           Chief Innovation Officer
# 4                                        Director II
#
#                             location  is_c_level              working_since  \
# 0             London, United Kingdom         0.0  2014-08-01 00:00:00+00:00
# 1                                NaN         0.0                        NaN
# 2  Greater Minneapolis-St. Paul Area         0.0  2017-04-01 00:00:00+00:00
# 3              Durham, New Hampshire         1.0  1994-01-01 00:00:00+00:00
# 4           Old Orchard Beach, Maine         0.0  1996-03-01 00:00:00+00:00
#
#                working_until is_current       working_until
# 0  2016-12-01 00:00:00+00:00      False                  NaN
# 1        2020-07-02 14:22:30       True  2020-07-02 13:51:36
# 2        2020-07-02 14:22:30       True  2020-07-02 13:51:36
# 3  2008-01-01 00:00:00+00:00      False                  NaN
# 4        2020-07-02 14:22:30       True  2020-07-02 13:51:36

# %%
#if the person is current employee, then value 1, else 0
people['is_current'] = people['is_current'].replace({True :1 , False : 0})
people.head()
# Out:
#    brand_uuid       id       full_name       company_slug  \
# 0    motorola  2015583  Michaël Maarek  motorola-mobility
# 1        ford     3501     Matt Monroe                NaN
# 2      target    26647     Paul Melson             target
# 3  timberland  2105414      Doug Clark                NaN
# 4      anthem  1087431  Leslie Lampert             anthem
#
#                       slug                          email  \
# 0            michaelmaarek             lemike10@gmail.com
# 1     matt-monroe-18217749                            NaN
# 2                  pmelson              pmelson@gmail.com
# 3      doug-clark-7ba36615  dclark@newenglandfootwear.com
# 4  leslie-lampert-b8552a10      leslie.lampert@anthem.com
#
#                                            job_title  \
# 0                               Key Account Director
# 1            Licensing Manager at Ford Motor Company
# 2  Senior Director, Cybersecurity Threat Intellig...
# 3                           Chief Innovation Officer
# 4                                        Director II
#
#                             location  is_c_level              working_since  \
# 0             London, United Kingdom         0.0  2014-08-01 00:00:00+00:00
# 1                                NaN         0.0                        NaN
# 2  Greater Minneapolis-St. Paul Area         0.0  2017-04-01 00:00:00+00:00
# 3              Durham, New Hampshire         1.0  1994-01-01 00:00:00+00:00
# 4           Old Orchard Beach, Maine         0.0  1996-03-01 00:00:00+00:00
#
#                working_until  is_current       working_until
# 0  2016-12-01 00:00:00+00:00         0.0                  NaN
# 1        2020-07-02 14:22:30         1.0  2020-07-02 13:51:36
# 2        2020-07-02 14:22:30         1.0  2020-07-02 13:51:36
# 3  2008-01-01 00:00:00+00:00         0.0                  NaN
# 4        2020-07-02 14:22:30         1.0  2020-07-02 13:51:36

# %%
#checking for missing values in location of people
people_df['location'].isnull().sum()
# Out:
# 169443

# %% [markdown]
# As of now, the people_df dataframe only has missing values in working_since column and location column. We keep them as it is for now. The location is not going to be usedlater on, so we don't need to worry about it. What we need to worry about is the working since column. This we will fill in after merging the datasets.

# %%
brand_data.head()
# Out:
#    brand_id      brand_uuid      brand_name  growth_score  \
# 0     17197          thekey  TheKey.Company       90.1626
# 1     17198             loq             LOQ       42.7846
# 2     17199  prim8teapparel         PRIM8TE       36.2267
# 3     17200   rickyandmicky   Ricky & Micky       36.7196
# 4     17202       mzwallace      MZ Wallace       50.7959
#
#    sudden_growth_score  sudden_growth_delta  acceleration_score  \
# 0              95.2407               5.0781             95.5051
# 1              16.8201             -25.9645             47.8179
# 2              42.0921               5.8654             50.5134
# 3              32.1556              -4.5640             49.1773
# 4               4.0522             -46.7437             47.1598
#
#    success_score is_physical_products_brand is_brickandmortar  founded  \
# 0        45.9109                       True             False   2017.0
# 1        46.1855                       True             False   2015.0
# 2        20.2461                       True             False   2017.0
# 3        31.8832                       True             False   2016.0
# 4        53.3311                       True              True   2000.0
#
#    employees_count generic_reseller store_is_subdomain
# 0              NaN            False              False
# 1              6.0            False              False
# 2              NaN            False              False
# 3              7.0            False              False
# 4             54.0            False              False

# %%
#if the brand is physical products brand, then value 1, else 0
brand_data['is_physical_products_brand'] = brand_data['is_physical_products_brand'].replace({True :1 , False : 0})


# if the brand is brick and mortar brand, then value 1, else 0
brand_data['is_brickandmortar'] = brand_data['is_brickandmortar'].replace({True :1 , False : 0})


# is the brand is a generic reseller, then value 1, else value 0
brand_data['generic_reseller'] = brand_data['generic_reseller'].replace({True :1 , False : 0})

brand_data.head()
# Out:
#    brand_id      brand_uuid      brand_name  growth_score  \
# 0     17197          thekey  TheKey.Company       90.1626
# 1     17198             loq             LOQ       42.7846
# 2     17199  prim8teapparel         PRIM8TE       36.2267
# 3     17200   rickyandmicky   Ricky & Micky       36.7196
# 4     17202       mzwallace      MZ Wallace       50.7959
#
#    sudden_growth_score  sudden_growth_delta  acceleration_score  \
# 0              95.2407               5.0781             95.5051
# 1              16.8201             -25.9645             47.8179
# 2              42.0921               5.8654             50.5134
# 3              32.1556              -4.5640             49.1773
# 4               4.0522             -46.7437             47.1598
#
#    success_score  is_physical_products_brand  is_brickandmortar  founded  \
# 0        45.9109                         1.0                0.0   2017.0
# 1        46.1855                         1.0                0.0   2015.0
# 2        20.2461                         1.0                0.0   2017.0
# 3        31.8832                         1.0                0.0   2016.0
# 4        53.3311                         1.0                1.0   2000.0
#
#    employees_count  generic_reseller store_is_subdomain
# 0              NaN               0.0              False
# 1              6.0               0.0              False
# 2              NaN               0.0              False
# 3              7.0               0.0              False
# 4             54.0               0.0              False

# %%
# merge the dataframes

combined = pd.merge(people, brand_data, on='brand_uuid')

combined.head()
# Out:
#   brand_uuid       id        full_name       company_slug  \
# 0   motorola  2015583   Michaël Maarek  motorola-mobility
# 1   motorola  2048222  Michael Roberts  motorola-mobility
# 2   motorola    60552  Pratod Kasbekar  motorola-mobility
# 3   motorola    60545  Pamela Ajaibela  motorola-mobility
# 4   motorola    60546     paul burnett                NaN
#
#                       slug                      email  \
# 0            michaelmaarek         lemike10@gmail.com
# 1         michaelroberts07    msajs.roberts@gmail.com
# 2  pratod-kasbekar-a088b64      pkasbekar@verizon.net
# 3           pamelaajaibela  pamelapajaibela@gmail.com
# 4    paul-burnett-73189b23      pburnett66@rogers.com
#
#                                            job_title                location  \
# 0                               Key Account Director  London, United Kingdom
# 1  Sr. Director of Product Strategy and Business ...  Greater San Diego Area
# 2  Senior Director of Program Management/Engineering           United States
# 3                                           Director  San Francisco Bay Area
# 4                                   Channel Director                  Canada
#
#    is_c_level              working_since  ... sudden_growth_score  \
# 0         0.0  2014-08-01 00:00:00+00:00  ...             -8.7785
# 1         0.0  2010-08-01 00:00:00+00:00  ...             -8.7785
# 2         0.0  2006-01-01 00:00:00+00:00  ...             -8.7785
# 3         0.0  2007-02-01 00:00:00+00:00  ...             -8.7785
# 4         0.0                        NaN  ...             -8.7785
#
#    sudden_growth_delta acceleration_score  success_score  \
# 0             -72.5444            46.6345         84.323
# 1             -72.5444            46.6345         84.323
# 2             -72.5444            46.6345         84.323
# 3             -72.5444            46.6345         84.323
# 4             -72.5444            46.6345         84.323
#
#   is_physical_products_brand  is_brickandmortar  founded  employees_count  \
# 0                        1.0                1.0   2017.0          26954.0
# 1                        1.0                1.0   2017.0          26954.0
# 2                        1.0                1.0   2017.0          26954.0
# 3                        1.0                1.0   2017.0          26954.0
# 4                        1.0                1.0   2017.0          26954.0
#
#    generic_reseller  store_is_subdomain
# 0               0.0               False
# 1               0.0               False
# 2               0.0               False
# 3               0.0               False
# 4               0.0               False
#
# [5 rows x 26 columns]

# %%
combined.columns
# Out:
# Index(['brand_uuid', 'id', 'full_name', 'company_slug', 'slug', 'email',
#        'job_title', 'location', 'is_c_level', 'working_since', 'working_until',
#        'is_current', 'working_until ', 'brand_id', 'brand_name',
#        'growth_score', 'sudden_growth_score', 'sudden_growth_delta',
#        'acceleration_score', 'success_score', 'is_physical_products_brand',
#        'is_brickandmortar', 'founded', 'employees_count', 'generic_reseller',
#        'store_is_subdomain'],
#       dtype='object')

# %%
combined.to_csv('final_combined.csv', index=False)
